# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')
import requests
import json

import tensorflow as tf
from tensorflow import keras

# %%
apiKey = 'fb7c606967de4f76b094f642dfb8dc8a'
url = 'http://newsapi.org/v2/everything?'
parameters = {
    'q': 'Amazon',
    'apiKey': apiKey,
    'language': 'en'
}
response = requests.get(url, params = parameters)
response = response.json()

# %%
response
# Out:
# {'status': 'ok',
#  'totalResults': 45258,
#  'articles': [{'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Brendan Hesse',
#    'title': "Play Your Free Twitch Prime Games With Amazon's New Games Launcher",
#    'description': 'One of the best Amazon Prime perks is its rotating selection of free games on offer each month through the Twitch.tv “Twitch Prime” service. Even better, Amazon now has a new Amazon Games launcher that makes it far easier to claim, download and play these gam…',
#    'url': 'https://lifehacker.com/play-your-free-twitch-prime-games-with-amazons-new-game-1844208153',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/vokeaqzgr9bsciwcelpu.jpg',
#    'publishedAt': '2020-06-29T20:30:00Z',
#    'content': 'One of the best Amazon Prime perks is its rotating selection of free games on offer each month through the Twitch.tvTwitch Prime service. Even better, Amazon now has a new Amazon Games launcher that … [+1991 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Nicole Lee',
#    'title': 'Amazon bans TikTok app on employee phones',
#    'description': 'Amazon has requested that all of its employees delete the TikTok app from their phones citing security concerns. According to the New York Times, the company email stated that the app is now prohibited from all employee phones that can “access Amazon email,” …',
#    'url': 'https://www.engadget.com/amazon-bans-tiktok-employee-phones-174810571.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2020-07%2F9ec52880-bf88-11ea-bfd9-894b79050bbf&client=amp-blogside-v2&signature=a9a219c875139697447602ea093d71796e0fed72',
#    'publishedAt': '2020-07-10T17:48:10Z',
#    'content': 'Amazon has requested that all of its employees delete the TikTok app from their phones citing security concerns. According to the New York Times, the company email stated that the app is now prohibit… [+724 chars]'},
#   {'source': {'id': None, 'name': 'Theinventory.com'},
#    'author': 'Elizabeth Henges on Kinja Deals, shared by Elizabeth Henges to Lifehacker',
#    'title': 'Be Comfortable in the Car and in the Office With a $10 Seat Warmer and Cooler',
#    'description': 'Naipo Warmer and Cooler Seat Cover | $10 | Amazon | Use code 2S2IE4EJ + clip couponRead more...',
#    'url': 'https://kinjadeals.theinventory.com/be-comfortable-in-the-car-and-in-the-office-with-a-25-1844270877',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ughj294pvkw3nen0imnx.jpg',
#    'publishedAt': '2020-07-05T12:58:00Z',
#    'content': 'Naipo Warmer and Cooler Seat Cover | $10 | Amazon | Use code 2S2IE4EJ + clip coupon\r\nIf you have a job that involves sitting or traveling a lot, you know how uncomfortable a seat can get sometimes. Y… [+541 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Ann Smajstrla',
#    'title': 'Amazon invests $2 billion in its clean energy fund',
#    'description': 'Amazon is committing $2 billion to companies developing clean energy technology with its Climate Pledge Fund, the company announced Tuesday. The fund is one facet of Amazon’s Climate Pledge, which aims to eliminate the company’s net carbon emissions by 2040. …',
#    'url': 'https://www.engadget.com/amazon-invests-2-billion-clean-energy-fund-183049118.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2020-04%2F6d49ab00-8a2c-11ea-9b7e-7e9c25713027&client=amp-blogside-v2&signature=3a0776a8d9b26fbad27efff4b75594c07bbf6744',
#    'publishedAt': '2020-06-23T18:30:49Z',
#    'content': 'Amazon is committing $2 billion to companies developing clean energy technology with its Climate Pledge Fund, the company announced Tuesday. The fund is one facet of Amazon’s Climate Pledge, which ai… [+578 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "Apple's latest iPad mini drops to $349 at Amazon",
#    'description': 'It’s now a little easier to get a small tablet that still packs a punch. Amazon is selling Apple’s current-generation iPad mini with 64GB of storage for $349, or $50 below the official price. You’ll get $50 off the price if you want 256GB of storage or LTE, t…',
#    'url': 'https://www.engadget.com/apple-ipad-mini-amazon-sale-143921486.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-06%2F568940e0-af0e-11ea-adf9-dbc90014df74&client=amp-blogside-v2&signature=88407c47670e9309f3f24e90bd778f7a751409b3',
#    'publishedAt': '2020-06-15T14:39:21Z',
#    'content': 'We called the iPad mini the “best small tablet” for good reason. It’s very fast compared to most tablets, and virtually unequalled in its size class — this is an easy choice if you want a compact tab… [+845 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "Apple's AirPods are at their lowest-ever price on Amazon",
#    'description': 'You might want to act quickly if you’ve been waiting for a sale on Apple’s AirPods Pro. Amazon is selling the noise-cancelling true wireless earbuds for $220 — that’s $30 off the usual sticker, and the lowest price we’ve seen on Amazon to date. That’s still m…',
#    'url': 'https://www.engadget.com/apple-airpods-pro-amazon-sale-234957987.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-06%2F0cf63c10-af5b-11ea-b47d-2898c24eade1&client=amp-blogside-v2&signature=d648240368d2b3f72f923aedfef061e38885d1db',
#    'publishedAt': '2020-06-15T23:49:57Z',
#    'content': 'The Pro models upgrade virtually every aspect of the experience. Most notably, they sound better — Adaptive EQ tunes the frequencies to your ear, while active noise cancellation prevents outside nois… [+922 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "Roku discounts its streaming devices ahead of Father's Day",
#    'description': 'Roku is hoping that you’ll buy a media streaming device for Father’s Day, and it’s running a sale on its players to match. Retailers like Amazon and Best Buy are selling Roku’s lineup significantly below their official prices, and it might be tempting if the …',
#    'url': 'https://www.engadget.com/roku-fathers-day-sale-231248236.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-06%2F1266f310-af51-11ea-bfeb-8f1da6bad535&client=amp-blogside-v2&signature=faccb11e4981855d359136791c45b907cabb3c3c',
#    'publishedAt': '2020-06-15T23:12:48Z',
#    'content': 'Buy Roku Ultra on Amazon - $80\r\nBuy Roku Ultra on Best Buy - $80\r\nRoku Premiere\r\nThere’s also a good deal to be had if you’re only looking for slightly more than the essentials. Amazon is selling the… [+818 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': 'EU will reportedly file antitrust charges against Amazon over seller data abuse',
#    'description': "Following a\xa0nearly year-long investigation\xa0into the company's business practices, the European Commission (EC) plans to announce formal antitrust charges against Amazon, according to the\xa0Wall Street Journal. The paper reports the charges will likely come some…",
#    'url': 'https://www.engadget.com/amazon-european-commission-antitrust-report-135254227.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2020-05%2F58992670-9d39-11ea-af7c-a27195feace0&client=amp-blogside-v2&signature=9a386234bc889868ae6ceee05bae4de031968c5e',
#    'publishedAt': '2020-06-11T13:52:54Z',
#    'content': "If the\xa0Wall Street Journal's reporting is accurate, the charges from the EC will be the latest instance of Amazon getting in trouble over its seller practices. Amazon's problems started in earnest fo… [+1134 chars]"},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': "Amazon's 'New World' MMO is delayed again",
#    'description': "Amazon is once delaying its upcoming colonial online RPG\xa0New World (via PCGamer). The company's Amazon Games studio\xa0says\xa0it now plans to release the game sometime in the spring of 2021. It's also delaying the title's final beta test to that same time frame.\xa0T…",
#    'url': 'https://www.engadget.com/new-world-delayed-2021-213019137.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-07%2F7a211400-c2ec-11ea-bfaf-2ae1d12bcc13&client=amp-blogside-v2&signature=1a8c8f36eb79c7fab3a170912ea89661576b00d5',
#    'publishedAt': '2020-07-10T21:30:19Z',
#    'content': 'When Amazon first announced\xa0New World, it initially planned to release the MMO in\xa0May 2020. Earlier this year, the company delayed the game to\xa0August 25th\xa0due to the coronavirus pandemic. As a kind o… [+731 chars]'},
#   {'source': {'id': None, 'name': 'Theinventory.com'},
#    'author': 'The Inventory Staff on Kinja Deals, shared by Andrew Hayward to Lifehacker',
#    'title': "Saturday's Best Deals: Instant Pot Duo Plus, Cubii Pro Under-Desk Elliptical, AirPods Pro, Bounty Hunter Metal Detectors, and More",
#    'description': 'An Instant Pot Duo Plus, Cubii Pro Under-Desk Elliptical, Apple AirPods Pro, Bounty Hunter metal detectors, Apple Watch Series 5, and the Eero Mesh Wi-Fi System with a free Amazon Echo Dot lead Saturday’s best deals.Read more...',
#    'url': 'https://kinjadeals.theinventory.com/saturdays-best-deals-instant-pot-duo-plus-cubii-pro-u-1843941486',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/tpw9rm8vesorglzcrhn1.png',
#    'publishedAt': '2020-06-20T15:05:00Z',
#    'content': 'An Instant Pot Duo Plus, Cubii Pro Under-Desk Elliptical, Apple AirPods Pro, Bounty Hunter metal detectors, Apple Watch Series 5, and the Eero Mesh Wi-Fi System with a free Amazon Echo Dot lead Satur… [+46167 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'David Nield',
#    'title': "Amazon Fire OS vs Android: What You'll Miss With an Amazon Device",
#    'description': 'Pick up a Fire TV device or an Amazon Fire tablet, and the on-board operating system is only loosely based on Android: You’re actually dealing with a modified OS, cut off from Google’s apps and services, but it’s not particularly clear exactly what that means…',
#    'url': 'https://gizmodo.com/amazon-fire-os-vs-android-what-youll-miss-with-an-amaz-1844025970',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/xddxdn6czr4pdtu1am6c.jpg',
#    'publishedAt': '2020-06-19T13:00:00Z',
#    'content': 'Pick up a Fire TV device or an Amazon Fire tablet, and the on-board operating system is only loosely based on Android: Youre actually dealing with a modified OS, cut off from Googles apps and service… [+7053 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Cameron Faulkner',
#    'title': 'TCL’s 10 Pro Android phone is $70 off at Amazon',
#    'description': 'TCL is mostly known for making TVs, but its new Android smartphone, the TCL 10 Pro, is worth checking out if you want a budget-friendly phone with a big display. It’s even more affordable at Amazon today, at $70 off its usual price.',
#    'url': 'https://www.theverge.com/good-deals/2020/6/26/21304271/tcl-10-pro-android-phone-unlocked-deal-sale-lucidsound-gaming-headset-amazon',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/tvqKmEk9IhabZOjM7n-rIhYzoNE=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/19969368/jporter_200507_4019_0007.0.jpg',
#    'publishedAt': '2020-06-26T14:58:01Z',
#    'content': 'Its a budget-friendly flagship phone with a great screen and a headphone jack\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.\r\nThis story is part o… [+1787 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Manish Singh',
#    'title': 'Amazon launches ‘Smart Stores’ in India to win mom and pop',
#    'description': 'For Amazon, it’s never too late to try something in India. The e-commerce giant is exploring ways to further spread its tentacles in the largely offline, technology-free neighborhood stores in the world’s second most populous nation. The American firm’s lates…',
#    'url': 'http://techcrunch.com/2020/06/26/amazon-launches-smart-stores-in-india-to-win-mom-and-pop/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1163035953.jpg?w=600',
#    'publishedAt': '2020-06-26T11:19:54Z',
#    'content': 'For Amazon, its never too late to try something in India. The e-commerce giant is exploring ways to further spread its tentacles in the largely offline, technology-free neighborhood stores in one of … [+3588 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Ingrid Lunden',
#    'title': 'UK’s CMA clears Amazon’s 16% Deliveroo stake, says COVID-19 impact less severe than initially thought',
#    'description': 'More than a year after Amazon announced that it would be lead a $575 million investment into UK food delivery startup Deliveroo, the country’s competition regulator, the CMA, has finally announced that it has provisionally cleared the deal. The investment, wh…',
#    'url': 'http://techcrunch.com/2020/06/24/uks-cma-clears-amazons-16-deliveroo-stake-says-covid-19-impact-less-severe-than-initially-thought/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/07/GettyImages-991304512.jpg?w=600',
#    'publishedAt': '2020-06-24T14:45:40Z',
#    'content': 'More than a year after Amazon announced that it would be lead a $575 million investment into UK food delivery startup Deliveroo, the country’s competition regulator, the CMA, has finally announced th… [+5107 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Sarah Perez',
#    'title': 'Amazon U.S. sellers will have to display their name and address starting Sept. 1, 2020',
#    'description': 'Amazon on Wednesday informed its U.S. sellers they will soon have to display their business name and address on their Amazon.com seller profile page. For individual sellers, this will include the individual’s name and address. A similar system is already in p…',
#    'url': 'http://techcrunch.com/2020/07/08/amazon-u-s-sellers-will-have-to-display-their-name-and-address-starting-sept-1-2020/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/10/GettyImages-535059003.jpg?w=600',
#    'publishedAt': '2020-07-08T18:40:51Z',
#    'content': 'Amazon on Wednesday informed its U.S. sellers they will soon have to display their business name and address on their Amazon.com seller profile page. For individual sellers, this will include the ind… [+3150 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Sarah Perez',
#    'title': 'Amazon Prime Video introduces ‘Watch Party,’ a social coviewing experience included with Prime',
#    'description': 'Amazon Prime Video is beginning to roll out a coviewing feature to Amazon Prime members in the U.S., the company announced today. The “Watch Party” feature, which is included at no extra cost with a Prime membership, allows participants to watch video content…',
#    'url': 'http://techcrunch.com/2020/06/29/amazon-prime-video-introduces-watch-party-a-social-coviewing-experience-included-with-prime/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/unnamed-6.png?w=722',
#    'publishedAt': '2020-06-29T22:30:09Z',
#    'content': 'Amazon Prime Video is beginning to roll out a coviewing feature to Amazon Prime members in the U.S., the company announced today. The “Watch Party” feature, which is included at no extra cost with a … [+3037 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Daily Crunch: Amazon buys self-driving startup Zoox',
#    'description': 'Amazon makes an autonomous driving acquisition, Microsoft closes its retail stores and health insurance startup Oscar raises $225 million. Here’s your Daily Crunch for June 26, 2020. 1. Amazon to acquire autonomous driving startup Zoox According to Amazon’s a…',
#    'url': 'http://techcrunch.com/2020/06/26/daily-crunch-amazon-buys-self-driving-startup-zoox/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/10/Zoox_LV_2019_005-1.jpg?w=711',
#    'publishedAt': '2020-06-26T16:25:44Z',
#    'content': 'Amazon makes an autonomous driving acquisition, Microsoft closes its retail stores and health insurance startup Oscar raises $225 million.\r\nHere’s your Daily Crunch for June 26, 2020.\r\n1. Amazon to a… [+3010 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Kim Lyons',
#    'title': 'Amazon is ending support for the Dash Wand barcode scanner',
#    'description': 'Amazon is ending support for its Dash Wand, an Alexa-enabled device that let users scan grocery barcodes and order household essentials. Shoppers can still use Alexa-enabled devices to add items to a shopping list, the company noted.',
#    'url': 'https://www.theverge.com/2020/6/21/21298198/amazon-alexa-support-dash-wand-shopping',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/_zGm-qBFqAeemP4TjQbHMU-A3LU=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8718175/akrales_170620_1791_0015.jpg',
#    'publishedAt': '2020-06-21T15:16:44Z',
#    'content': 'The device let users scan barcodes to add to an Alexa shopping list\r\nPhoto by Amelia Holowaty Krales / The Verge\r\nAmazon is ending support for its Dash Wand, an Alexa-enabled device that let shoppers… [+916 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Justine Calma',
#    'title': 'Amazon boosts climate commitments and greenhouse gas emissions',
#    'description': 'Amazon launched a new $2 billion climate change fund. On the same day, it released data showing that its carbon footprint is still growing.',
#    'url': 'https://www.theverge.com/2020/6/23/21300427/amazon-climate-change-commitments-greenhouse-gas-emissions-jeff-bezos',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/bXta_43aZa8iIccYMwMXkX7boQk=/0x371:5184x3085/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/20048916/1175733547.jpg.jpg',
#    'publishedAt': '2020-06-23T16:21:57Z',
#    'content': 'It announced a new climate change fund but revealed that its pollution is still growing \r\nAmazon CEO Jeff Bezos announces the co-founding of The Climate Pledge at the National Press Club on September… [+1957 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "Amazon places 'moratorium' on police use of its facial recognition tech",
#    'description': 'Amazon is temporarily halting the use of its controversial facial recognition technology in the wake of widespread protests against police violence and discrimination. The internet giant is starting a year-long “moratorium” on police use of Rekognition. The p…',
#    'url': 'https://www.engadget.com/amazon-moratorium-on-rekognition-use-by-police-214316554.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2020-06%2F31334610-ab62-11ea-9fbb-a4dca49ee546&client=amp-blogside-v2&signature=5be04c72aeb43e03a7ae9d2e0009a12d4612791e',
#    'publishedAt': '2020-06-10T21:43:16Z',
#    'content': 'Amazon is temporarily halting the use of its controversial facial recognition technology in the wake of widespread protests against police violence and discrimination. The internet giant is starting … [+453 chars]'}]}
